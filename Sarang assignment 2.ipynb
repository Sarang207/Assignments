# %% [markdown]
# ![DocScanner%2027-Dec-2023%2012-20%20pm_1.jpg](attachment:DocScanner%2027-Dec-2023%2012-20%20pm_1.jpg)

# %% [markdown]
# ![DocScanner%2027-Dec-2023%2012-20%20pm_2.jpg](attachment:DocScanner%2027-Dec-2023%2012-20%20pm_2.jpg)

# %% [markdown]
# ![DocScanner%2027-Dec-2023%2012-20%20pm_3.jpg](attachment:DocScanner%2027-Dec-2023%2012-20%20pm_3.jpg)

# %% [markdown]
# ![DocScanner%2027-Dec-2023%2012-20%20pm_4.jpg](attachment:DocScanner%2027-Dec-2023%2012-20%20pm_4.jpg)

# %% [markdown]
# ![DocScanner%2027-Dec-2023%2012-20%20pm_5.jpg](attachment:DocScanner%2027-Dec-2023%2012-20%20pm_5.jpg)

# %% [markdown]
# ![DocScanner%2027-Dec-2023%2012-20%20pm_6.jpg](attachment:DocScanner%2027-Dec-2023%2012-20%20pm_6.jpg)
